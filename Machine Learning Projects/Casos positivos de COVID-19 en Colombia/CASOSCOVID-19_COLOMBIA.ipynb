# %%
# Importando las librerías
import numpy as np
import pandas as pd
from sodapy import Socrata
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Cargando el dataset: Un millón de casos.

# %%
# Cargando el dataset

# Un cliente no autenticado solo trabaja con datasets públicos. Note 'None'
client = Socrata("www.datos.gov.co", None)

# Primeros 1_000_000 resultados, retornados como un JSON desde la API, convertidos a una lista de
# diccionarios de Python
results = client.get("gt2j-8ykr", limit=1_000_000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#          fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0         6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1         9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2         9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3        11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4        11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                    ...        ...                   ...          ...
# 999995  24/10/2020 0:00:00    1000036    17/10/2020 0:00:00           18
# 999996  24/10/2020 0:00:00    1000037    15/10/2020 0:00:00           76
# 999997  24/10/2020 0:00:00    1000038    15/10/2020 0:00:00           25
# 999998  24/10/2020 0:00:00    1000039    19/10/2020 0:00:00           76
# 999999  24/10/2020 0:00:00    1000040    16/10/2020 0:00:00           25
#
#        departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...
